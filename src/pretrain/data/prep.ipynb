# %% [markdown]
# ## 데이터셋 다운로드
# 1. **ICBHI** : 코드에 포함되어 있음
# 2. **HF_Lung_V1**
# ```bash
# git clone https://gitlab.com/techsupportHF/HF_Lung_V1.git
# apt-get install p7zip-full
# 7zr x test.7z.001
# 7zr x train.7z.001
# ```
# 3. **Chest wall lung sounds**
# ```bash
# wget https://prod-dcd-datasets-cache-zipfiles.s3.eu-west-1.amazonaws.com/jwyy9np4gv-3.zip
# unzip jwyy9np4gv-3.zip
# ```

# %%
# chest wall dataset wav 파일 이름 변경
# path = './audio_files/'
# for filename in os.listdir(path):
#     print(filename)
#     new_filename = filename.replace(" ","-").replace(",","_")
#     if new_filename != filename:
#         os.rename(path+filename, path+new_filename)
#     print(new_filename)

# %%
# chest_wall Dataset 리샘플링 및 json 파일 생성 
# import os
# import sys
# import time
# import json

# def prep(basepath, targetpath, name):
#     if os.path.exists(targetpath) == False:
#         os.mkdir(targetpath)

#     sample_cnt = 0
#     pathdata = os.walk(basepath)
#     wav_list = []
#     begin_time = time.time()

#     for root, dirs, files in pathdata:
#         for file in files:
#             if file.endswith('.wav'):
#                 sample_cnt += 1

#                 # convert all samples to 16kHZ
#                 os.system('sox ' + basepath + file + ' -r 16000 ' + targetpath + file + ' > /dev/null 2>&1')

#                 # give a dummy label of 'audio' ('Normal' in ICBHI label ontology) to all samples
#                 # the label is not used in the pretraining, it is just to make the dataloader.py satisfy.
#                 cur_dict = {'wav': targetpath + file, 'label': 'Normal'}
#                 wav_list.append(cur_dict)

#                 if sample_cnt % 1000 == 0:
#                     end_time = time.time()
#                     print('find {:d}k .wav files, time eclipse: {:.1f} seconds.'.format(int(sample_cnt/1000), end_time-begin_time))
#                     begin_time = end_time

#     print(sample_cnt)
#     with open(name + '.json', 'w') as f:
#         json.dump({'data': wav_list}, f, indent=1)
        
# if os.system("which sox") != 0:
#     print("sox is not installed.")
#     sys.exit(1) 
    
# basepath = '/workspace/pj_resp/ssast/src/pretrain/data/chest_wall/audio/'
# targetpath = '/workspace/pj_resp/ssast/src/pretrain/data/chest_wall/audio_16k/'
# name = 'chest_wall'
# prep(basepath, targetpath, name)

# %%
# HF_Lung_V1 Dataset 리샘플링 및 json 파일 생성 
# import os
# import sys
# import time
# import json

# def prep(paths, targetpath, name):
#     if os.path.exists(targetpath) == False:
#         os.mkdir(targetpath)

#     sample_cnt = 0
#     wav_list = []
#     begin_time = time.time()
    
#     for basepath in paths:
#         pathdata = os.walk(basepath)
#         for root, dirs, files in pathdata:
#             for file in files:
#                 if file.endswith('.wav'):
#                     sample_cnt += 1

#                     # convert all samples to 16kHZ
#                     os.system('sox ' + basepath + file + ' -r 16000 ' + targetpath + file + ' > /dev/null 2>&1')

#                     # give a dummy label of 'audio' ('Normal' in ICBHI label ontology) to all samples
#                     # the label is not used in the pretraining, it is just to make the dataloader.py satisfy.
#                     cur_dict = {'wav': targetpath + file, 'label': 'Normal'}
#                     wav_list.append(cur_dict)

#                     if sample_cnt % 1000 == 0:
#                         end_time = time.time()
#                         print('find {:d}k .wav files, time eclipse: {:.1f} seconds.'.format(int(sample_cnt/1000), end_time-begin_time))
#                         begin_time = end_time

#     print(sample_cnt)
#     with open(name + '.json', 'w') as f:
#         json.dump({'data': wav_list}, f, indent=1)
        
# if os.system("which sox") != 0:
#     print("sox is not installed.")
#     sys.exit(1) 
    
# paths = ['/workspace/pj_resp/ssast/src/pretrain/data/HF_Lung_V1/test/', '/workspace/pj_resp/ssast/src/pretrain/data/HF_Lung_V1/audio/train/']
# targetpath = '/workspace/pj_resp/ssast/src/pretrain/data/HF_Lung_V1/audio_16k/'
# name = 'HF_Lung_V1'
# prep(paths, targetpath, name)
